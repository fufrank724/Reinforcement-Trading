# %%
from RL_brain import QLearningTable
from env2 import stock
import matplotlib.pyplot as plt
import pandas as pd
import time,random

env = stock(start="2001-01-01",end="2010-01-01")
RL = QLearningTable(actions=list(range(0,env.n_actions)))

#RL.q_table = pd.read_csv('ql_brain.csv', index_col='index')
#print(RL.actions)
RL.q_table.head()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
def update(env):
    #fig1 = plt.figure()  
    #plt.ion() 
        
    for episode in range(10000):
        if episode%200==0:
            step = 0    
        #plt.cla()
        # initial observation
        state = env.reset()

        for i in range(500):
            
            # RL choose action based on observation
            action = RL.choose_action(str(state))

            # RL take action and get next observation and reward
            state, reward,_state= env.step(action)
            #print(action)

            # RL learn from this transition
            RL.learn(str(state), action, reward, str(_state))

            # swap observation
            env.s=_state

            # break while loop when end of this episode
            
        if episode%10==0:
            print("episode = ",episode)
            print("performance: ",env.user.profitfactor)
            try:
                RL.q_table.to_csv("ql_brain.csv")
            except:
                print("output failed")
        env.performance=[]

# %%
update(env)
#RL.q_table.to_csv("ql_brain.csv")
# Out:
# episode =  0
# performance:  -0.953460620525
# episode =  10
# performance:  -0.634920634921
# episode =  20
# performance:  -2.31979695431
# episode =  30
# performance:  -1.92674805771
# episode =  40
# performance:  -1.89593908629
# episode =  50
# performance:  -2.66062602965
# episode =  60
# performance:  -2.0467032967
# episode =  70
# performance:  -1.87096774194
# episode =  80
# performance:  -3.99738903394
# episode =  90
# performance:  0.480565371025
# episode =  100
# performance:  -2.84632768362
# episode =  110
# performance:  -1.46423357664
# episode =  120
# performance:  -2.06300268097
# episode =  130
# performance:  -1.31111111111
# episode =  140
# performance:  -2.94701986755
# episode =  150
# performance:  -1.51246882793
# episode =  160
# performance:  -0.552188552189
# episode =  170
# performance:  -1.42240587695
# episode =  180
# performance:  -0.962199312715
# episode =  190
# performance:  -1.93536121673
# episode =  200
# performance:  -2.60047281324
# episode =  210
# performance:  2.589958159
# episode =  220
# performance:  -0.518771331058
# episode =  230
# performance:  -0.262745098039
# episode =  240
# performance:  2.43396226415
# episode =  250
# performance:  -0.679197994987
# episode =  260
# performance:  -0.856763925729
# episode =  270
# performance:  0.210424710425
# episode =  280
# performance:  0.164335664336
# episode =  290
# performance:  0.0125260960334
# episode =  300
# performance:  -0.294915254237
# episode =  310
# performance:  -1.16111111111
# episode =  320
# performance:  1.19069767442
# episode =  330
# performance:  -1.40639269406
# episode =  340
# performance:  4.36885245902
# episode =  350
# performance:  -0.517611026034
# episode =  360
# performance:  -0.261904761905
# episode =  370
# performance:  -0.897384305835
# episode =  380
# performance:  0.280871670702
# episode =  390
# performance:  0.760330578512
# episode =  400
# performance:  3.38078291815
# episode =  410
# performance:  3.61184210526
# episode =  420
# performance:  0.111336032389
# episode =  430
# performance:  -0.118299445471
# episode =  440
# performance:  1.90666666667
# episode =  450
# performance:  0.197986577181
# episode =  460
# performance:  0.263959390863
# episode =  470
# performance:  -0.244552058111
# episode =  480
# performance:  -0.351851851852
# episode =  490
# performance:  -1.03225806452
# episode =  500
# performance:  1.41046277666
# episode =  510
# performance:  -0.847549909256
# episode =  520
# performance:  -1.64139020537
# episode =  530
# performance:  -0.172413793103
# episode =  540
# performance:  -0.232608695652
# episode =  550
# performance:  -0.194552529183
# episode =  560
# performance:  0.995535714286
# E:\Python\Python\jupyter\futures\QL2\account.py:34: RuntimeWarning: divide by zero encountered in double_scalars
#   self.sharpe=np.sqrt(len(perform)) * np.mean(perform) / np.std(perform)
# episode =  570
# performance:  -0.0544871794872
# episode =  580
# performance:  -0.54126984127
# episode =  590
# performance:  0.61295971979
# episode =  600
# performance:  -0.146118721461
# episode =  610
# performance:  0.377622377622
# episode =  620
# performance:  2.14893617021
# episode =  630
# performance:  0.726851851852
# episode =  640
# performance:  1.72286374134
# episode =  650
# performance:  -0.272117962466
# episode =  660
# performance:  2.12529550827
# episode =  670
# performance:  0.348432055749
# episode =  680
# performance:  0.173848439822
# episode =  690
# performance:  1.53971962617
# episode =  700
# performance:  -0.0342465753425
# episode =  710
# performance:  0.386363636364
# episode =  720
# performance:  -0.0230149597238
# episode =  730
# performance:  -0.0841683366733
# episode =  740
# performance:  0.0989505247376
# episode =  750
# performance:  -0.180357142857
# episode =  760
# performance:  -0.0471567267684
# episode =  770
# performance:  -0.269406392694
# episode =  780
# performance:  -0.392273402675
# episode =  790
# performance:  -0.231382978723
# episode =  800
# performance:  -0.245387453875
# episode =  810
# performance:  -0.940652818991
# episode =  820
# performance:  -0.687022900763
# episode =  830
# performance:  -0.207439198856
# episode =  840
# performance:  -1.34317862166
# episode =  850
# performance:  -1.07424242424
# episode =  860
# performance:  -0.695
# episode =  870
# performance:  -0.401055408971
# episode =  880
# performance:  -0.165354330709
# episode =  890
# performance:  -0.869005847953
# episode =  900
# performance:  -1.12607944732
# episode =  910
# performance:  -1.84724409449
# episode =  920
# performance:  -1.47960992908
# episode =  930
# performance:  -0.764705882353
# episode =  940
# performance:  -0.0588235294118
# episode =  950
# performance:  -0.395112016293
# episode =  960
# performance:  0.208897485493
# episode =  970
# performance:  -1.25357873211
# episode =  980
# performance:  0.147577092511
# episode =  990
# performance:  0.0565068493151

# %%
RL.q_table = pd.read_csv('ql_brain.csv', index_col='index')

# %%
new_env=stock(start="2013-01-01",end="2017-01-01")
update(new_env)
print(new_env.user[0])
# Out:
# performance:  -786.0
# 0
# 0.0003528691057765531
# -786.0

# %%
import random
print(random.randint(0,2))
# Out:
# 1
